# %% [markdown]
# ## Data Exploration

# %%
# Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# Data manipulation and analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# OS operations, regex, and NLP tools
import os
import re
import nltk
from nltk.corpus import stopwords

# Modify Python path
import sys
sys.path.insert(0, '../')

# Import data processing functions
from utils.data import (
    save_processed_data, 
    load_data_to_dataset, 
    remove_duplicates, 
    remove_outliers, 
    display_data, 
    convert_to_classification_dataset
)

from datasets import load_from_disk

# %%
# Define the path to the data folder and the common file prefix
data_folder = '../../data/'
file_prefix = 'biased.'

# %%
# Construct the full paths for the datasets
data_full = data_folder + file_prefix + 'full'
data_train = data_folder + file_prefix + 'word.train'
data_test = data_folder + file_prefix + 'word.test'
data_dev = data_folder + file_prefix + 'word.dev'

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# 1. **id:** A unique identifier used to link to a Wikipedia Diff view
#
#     _Example:_ 532355971 (Links to https://en.wikipedia.org/w/index.php?diff=532355971)
#
# 2. **src_tok:** Tokenized source text
#
#     _Example:_ she did not do as promised exposing her as an un ##pr ##in ##ci ##pled politician .
#
# 3. **tgt_tok:** Tokenized target text
#
#     _Example:_ she did not do , leading to accusations of her being an un ##pr ##in ##ci ##pled politician
#
# 4. **src_raw:** Raw source text
#
#     _Example:_ she did not do as promised exposing her as an unprincipled politician.
#
# 5. **tgt_raw:** Raw target text
#
#     _Example:_ she did not do , leading to accusations of her being an unprincipled politician.
#
# 6. **src_POS_tags:** Part-of-speech tags for the source text
#
#     _Example:_ PRON VERB ADV VERB ADP VERB VERB PRON ADP DET ADJ ADJ ADJ ADJ ADJ NOUN PUNCT
#
# 7. **tgt_parse_tags:** Syntactic parse tags for the target text using the Stanford Parser
#
#     _Example:_ nsubj aux neg ROOT mark advcl xcomp dobj prep det amod amod amod amod amod pobj punct

# %%
# Load datasets from their respective files
full = pd.read_csv(data_full, sep='\t', names=["id", "src_tok", "tgt_tok", "src_raw", "tgt_raw", "src_POS_tags", "tgt_parse_tags"], on_bad_lines='skip')
train = pd.read_csv(data_train, sep='\t', names=["id", "src_tok", "tgt_tok", "src_raw", "tgt_raw", "src_POS_tags", "tgt_parse_tags"])
test = pd.read_csv(data_test, sep='\t', names=["id", "src_tok", "tgt_tok", "src_raw", "tgt_raw", "src_POS_tags", "tgt_parse_tags"])
dev = pd.read_csv(data_dev, sep='\t', names=["id", "src_tok", "tgt_tok", "src_raw", "tgt_raw", "src_POS_tags", "tgt_parse_tags"])

# %%
full.head()
# Out:
#           id                                            src_tok  \
# 0  258378316  during the campaign , controversy erupted over...
# 1  486527143  nic ##aea was con ##vo ##ked by the emperor co...
# 2   54024499  it was rather unfortunate that he ve ##hem ##e...
# 3  160186886  dennis the menace is an american animated seri...
# 4    8797183  today , on large farms , motorcycles , dogs or...
#
#                                              tgt_tok  \
# 0  during the campaign , some pointed out alleged...
# 1  nic ##aea was con ##vo ##ked by the emperor co...
# 2  he ve ##hem ##ently opposed the bud ##ding ind...
# 3  dennis the menace is an american animated seri...
# 4  today , on large farms , motorcycles , dogs or...
#
#                                              src_raw  \
# 0  during the campaign, controversy erupted over ...
# 1  nicaea was convoked by the emperor constantine...
# 2  it was rather unfortunate that he vehemently o...
# 3  dennis the menace is an american animated seri...
# 4  today, on large farms, motorcycles, dogs or me...
#
#                                              tgt_raw  \
# 0  during the campaign, some pointed out alleged ...
# 1  nicaea was convoked by the emperor constantine...
# 2  he vehemently opposed the budding indian scien...
# 3  dennis the menace is an american animated seri...
# 4  today, on large farms, motorcycles, dogs or pe...
#
#                                         src_POS_tags  \
# 0  ADP DET NOUN PUNCT NOUN VERB ADP VERB NOUN ADP...
# 1  NOUN NOUN VERB VERB VERB VERB ADP DET NOUN NOU...
# 2  PRON VERB ADV ADJ ADP PRON ADV ADV ADV VERB DE...
# 3  VERB DET NOUN VERB DET ADJ VERB NOUN VERB ADP ...
# 4  NOUN PUNCT ADP ADJ NOUN PUNCT NOUN PUNCT NOUN ...
#
#                                       tgt_parse_tags
# 0  prep det pobj punct nsubj ROOT prep amod pobj ...
# 1  nsubjpass nsubjpass auxpass ROOT ROOT ROOT age...
# 2  nsubj ROOT advmod acomp mark nsubj advmod advm...
# 3  csubj det dobj ROOT det amod amod attr acl age...
# 4  npadvmod punct prep amod pobj punct conj punct...

# %%
train.head()
# Out:
#           id                                            src_tok  \
# 0  165188319  ch ##lor ##of ##or ##m " the molecular life ##...
# 1  123204846  the free software gnu class ##path project is ...
# 2  706783956  other campaign ##ers , especially the controve...
# 3  612378448  vocalist rob half ##ord ' s performance is con...
# 4  876796337  the proud general is a chinese animated featur...
#
#                                              tgt_tok  \
# 0  ch ##lor ##of ##or ##m " the molecular life ##...
# 1  the free software gnu class ##path project is ...
# 2  other campaign ##ers , especially the british ...
# 3  vocalist rob half ##ord ' s performance is con...
# 4  the proud general is a chinese animated featur...
#
#                                              src_raw  \
# 0  chloroform "the molecular lifesaver" an articl...
# 1  the free software gnu classpath project is onl...
# 2  other campaigners, especially the controversia...
# 3  vocalist rob halford's performance is consider...
# 4  the proud general is a chinese animated featur...
#
#                                              tgt_raw  \
# 0  chloroform "the molecular lifesaver" an articl...
# 1  the free software gnu classpath project is par...
# 2  other campaigners, especially the british acti...
# 3  vocalist rob halford's performance is consider...
# 4  the proud general is a chinese animated featur...
#
#                                         src_POS_tags  \
# 0  NOUN NOUN NOUN NOUN NOUN PUNCT DET ADJ NOUN NO...
# 1  DET ADJ NOUN NOUN NOUN NOUN NOUN VERB ADV ADV ...
# 2  ADJ NOUN NOUN PUNCT ADV DET ADJ ADJ NOUN ADJ N...
# 3  ADJ X NOUN NOUN PUNCT PART NOUN VERB VERB NUM ...
# 4  DET ADJ NOUN VERB DET ADJ VERB NOUN NOUN VERB ...
#
#                                       tgt_parse_tags
# 0  ROOT ROOT ROOT ROOT ROOT punct det amod dobj d...
# 1  det amod nmod compound compound compound nsubj...
# 2  amod nsubj nsubj punct advmod det amod amod am...
# 3  amod amod poss poss punct case nsubjpass auxpa...
# 4  det amod nsubj ROOT det amod amod attr attr ac...

# %%
test.head()
# Out:
#           id                                            src_tok  \
# 0  318427508  in april 2009 a brazilian human rights group ,...
# 1  235640083  the 51 day stand ##off and ensuing murder of 7...
# 2   37561168  mark o ##ate ##n ( born 8 march 1964 , watford...
# 3  101665256  another infamous period of colon ##isation in ...
# 4  480248865  photo sequence of astonishing 2005 chicago ##l...
#
#                                              tgt_tok  \
# 0  in april 2009 a brazilian human rights group ,...
# 1  the 51 day stand ##off and ensuing deaths of 7...
# 2  mark o ##ate ##n ( born 8 march 1964 , watford...
# 3  another period of colon ##isation in ancient t...
# 4  photo sequence of 2005 chicago ##land crash wi...
#
#                                              src_raw  \
# 0  in april 2009 a brazilian human rights group, ...
# 1  the 51 day standoff and ensuing murder of 76 m...
# 2  mark oaten (born 8 march 1964, watford) is a d...
# 3  another infamous period of colonisation in anc...
# 4  photo sequence of astonishing 2005 chicagoland...
#
#                                              tgt_raw  \
# 0  in april 2009 a brazilian human rights group, ...
# 1  the 51 day standoff and ensuing deaths of 76 m...
# 2  mark oaten (born 8 march 1964, watford) is a l...
# 3  another period of colonisation in ancient time...
# 4  photo sequence of 2005 chicagoland crash with ...
#
#                                         src_POS_tags  \
# 0  ADP NOUN NUM DET ADJ ADJ NOUN NOUN PUNCT NOUN ...
# 1  DET NUM NOUN NOUN NOUN CCONJ VERB NOUN ADP NUM...
# 2  NOUN ADJ ADJ ADJ PUNCT VERB NUM NOUN NUM PUNCT...
# 3  DET ADJ NOUN ADP NOUN NOUN ADP ADJ NOUN VERB A...
# 4  NOUN NOUN ADP VERB NUM NOUN NOUN NOUN ADP ADJ ...
#
#                                       tgt_parse_tags
# 0  prep pobj nummod det amod amod compound nsubj ...
# 1  det nummod compound nsubj nsubj cc amod conj p...
# 2  nsubj amod amod amod punct parataxis nummod np...
# 3  det amod nsubj prep pobj pobj prep amod pobj R...
# 4  compound ROOT prep amod nummod compound compou...

# %%
dev.head()
# Out:
#           id                                            src_tok  \
# 0    3257810  in addition to sponsoring palestinian terror a...
# 1    7455549  the game is currently played in 47 countries w...
# 2  524547829  no part of the valley lies in the area current...
# 3  842911055  scholars perceived that it was disco ##rdan ##...
# 4  302188700  since the chinese civil war in 1949 , taiwan h...
#
#                                              tgt_tok  \
# 0  in addition to sponsoring palestinian attacks ...
# 1  the game claims to be currently played in 47 c...
# 2  no part of the valley lies in the area current...
# 3  scholars argued that it was disco ##rdan ##t w...
# 4  since the chinese civil war in 1949 , taiwan h...
#
#                                              src_raw  \
# 0  in addition to sponsoring palestinian terror a...
# 1  the game is currently played in 47 countries w...
# 2  no part of the valley lies in the area current...
# 3  scholars perceived that it was discordant with...
# 4  since the chinese civil war in 1949, taiwan ha...
#
#                                              tgt_raw  \
# 0  in addition to sponsoring palestinian attacks ...
# 1  the game claims to be currently played in 47 c...
# 2  no part of the valley lies in the area current...
# 3  scholars argued that it was discordant with th...
# 4  since the chinese civil war in 1949, taiwan ha...
#
#                                         src_POS_tags  \
# 0  ADP NOUN ADP VERB ADJ NOUN NOUN ADP PROPN PUNC...
# 1  DET NOUN VERB ADV VERB ADP NUM NOUN ADP ADJ AD...
# 2  DET NOUN ADP DET NOUN VERB ADP DET NOUN ADV VE...
# 3  NOUN VERB ADP PRON VERB ADJ ADJ ADJ ADP DET AD...
# 4  ADP DET ADJ ADJ NOUN ADP NUM PUNCT PROPN VERB ...
#
#                                       tgt_parse_tags
# 0  prep pobj prep pcomp amod compound dobj prep p...
# 1  det nsubjpass auxpass advmod ROOT prep nummod ...
# 2  det nsubj prep det pobj ROOT prep det pobj adv...
# 3  nsubj ROOT mark nsubj ccomp acomp acomp acomp ...
# 4  prep det amod amod pobj prep pobj punct nsubjp...

# %%
# Check number of rows in the datasets
display(full.shape)
display(train.shape)
display(test.shape)
display(dev.shape)
# Out:
# (53803, 7)
# (1000, 7)
# (700, 7)

# %%
# Sample row for full dataset
for col in full.columns:
    print(col, full[col][78])
# Out:
# id 755060188
# src_tok unlike the previous films , a good day to die hard was the first die hard film to be a critical failure , receiving overwhelmingly negative reviews for its imp ##laus ##ible action sequences , cl ##iche ##d script , weak plot , moore ' s direction , and lack of characterization , although the special effects were praised .
# tgt_tok unlike the previous films , a good day to die hard was the first die hard film to be a critical failure , receiving overwhelmingly negative reviews which cited imp ##laus ##ible action sequences , cl ##iche ##d script , weak plot , moore ' s direction , and lack of characterization , although the special effects were praised .
# src_raw unlike the previous films, a good day to die hard was the first die hard film to be a critical failure, receiving overwhelmingly negative reviews for its implausible action sequences, cliched script, weak plot, moore's direction, and lack of characterization, although the special effects were praised.
# tgt_raw unlike the previous films, a good day to die hard was the first die hard film to be a critical failure, receiving overwhelmingly negative reviews which cited implausible action sequences, cliched script, weak plot, moore's direction, and lack of characterization, although the special effects were praised.
# src_POS_tags ADP DET ADJ NOUN PUNCT DET ADJ NOUN PART VERB ADJ VERB DET ADJ VERB ADJ NOUN PART VERB DET ADJ NOUN PUNCT VERB ADV ADJ NOUN ADP ADJ ADJ ADJ ADJ NOUN NOUN PUNCT ADJ ADJ ADJ NOUN PUNCT ADJ NOUN PUNCT NOUN PUNCT VERB NOUN PUNCT CCONJ NOUN ADP NOUN PUNCT ADP DET ADJ NOUN VERB VERB PUNCT
# tgt_parse_tags prep det amod pobj punct det amod nsubj aux relcl advmod ROOT det advmod amod amod nsubj aux relcl det amod attr punct advcl advmod amod dobj prep poss amod amod amod compound pobj punct amod amod amod conj punct amod conj punct poss punct compound conj punct cc conj prep pobj punct mark det amod nsubjpass auxpass advcl punct

# %%
# Sample row for train dataset
for col in train.columns:
    print(col, train[col][78])
# Out:
# id 815664961
# src_tok there he lived in a single room flat at the renowned ana ##rka ##li bazaar , lahore .
# tgt_tok there he lived in a single room flat at the ana ##rka ##li bazaar , lahore .
# src_raw there he lived in a single room flat at the renowned anarkali bazaar, lahore.
# tgt_raw there he lived in a single room flat at the anarkali bazaar, lahore.
# src_POS_tags ADV PRON VERB ADP DET ADJ NOUN ADJ ADP DET ADJ ADJ ADJ ADJ NOUN PUNCT NOUN PUNCT
# tgt_parse_tags advmod nsubj ROOT prep det amod pobj amod prep det amod amod amod amod pobj punct npadvmod punct

# %% [markdown]
# ## Data Transformation

# %%
# Load the data
dataset_dict = load_data_to_dataset(data_folder)
# Out:
# Map:   0%|          | 0/53803 [00:00<?, ? examples/s]
# Map:   0%|          | 0/700 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
# Display the loaded data
display_data(dataset_dict)
# Out:
# train dataset:
# Dataset({
#     features: ['id', 'src_tok', 'tgt_tok', 'src_raw', 'tgt_raw', 'src_POS_tags', 'tgt_parse_tags', 'source', 'target'],
#     num_rows: 53803
# })
#
# Sample rows:
# {'id': 165188319, 'src_tok': 'ch ##lor ##of ##or ##m " the molecular life ##sa ##ver " an article at oxford university providing interesting facts about ch ##lor ##of ##or ##m .', 'tgt_tok': 'ch ##lor ##of ##or ##m " the molecular life ##sa ##ver " an article at oxford university providing facts about ch ##lor ##of ##or ##m .', 'src_raw': 'chloroform "the molecular lifesaver" an article at oxford university providing interesting facts about chloroform.', 'tgt_raw': 'chloroform "the molecular lifesaver" an article at oxford university providing facts about chloroform.', 'src_POS_tags': 'NOUN NOUN NOUN NOUN NOUN PUNCT DET ADJ NOUN NOUN NOUN PUNCT DET NOUN ADP NOUN NOUN VERB ADJ NOUN ADP NOUN NOUN NOUN NOUN NOUN PUNCT', 'tgt_parse_tags': 'ROOT ROOT ROOT ROOT ROOT punct det amod dobj dobj dobj punct det appos prep compound pobj acl amod dobj prep pobj pobj pobj pobj pobj punct', 'source': 'chloroform "the molecular lifesaver" an article at oxford university providing interesting facts about chloroform.', 'target': 'chloroform "the molecular lifesaver" an article at oxford university providing facts about chloroform.'}
# {'id': 123204846, 'src_tok': 'the free software gnu class ##path project is only partially compatible with the current version of sun java .', 'tgt_tok': 'the free software gnu class ##path project is partially compatible with the current version of sun java .', 'src_raw': 'the free software gnu classpath project is only partially compatible with the current version of sun java.', 'tgt_raw': 'the free software gnu classpath project is partially compatible with the current version of sun java.', 'src_POS_tags': 'DET ADJ NOUN NOUN NOUN NOUN NOUN VERB ADV ADV ADJ ADP DET ADJ NOUN ADP NOUN NOUN PUNCT', 'tgt_parse_tags': 'det amod nmod compound compound compound nsubj ROOT advmod advmod acomp prep det amod pobj prep compound pobj punct', 'source': 'the free software gnu classpath project is only partially compatible with the current version of sun java.', 'target': 'the free software gnu classpath project is partially compatible with the current version of sun java.'}
# {'id': 706783956, 'src_tok': 'other campaign ##ers , especially the controversial british activist peter ta ##tch ##ell , attacked him for questioning the universal validity of gay identity .', 'tgt_tok': 'other campaign ##ers , especially the british activist peter ta ##tch ##ell , attacked him for questioning the universal validity of gay identity .', 'src_raw': 'other campaigners, especially the controversial british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'tgt_raw': 'other campaigners, especially the british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'src_POS_tags': 'ADJ NOUN NOUN PUNCT ADV DET ADJ ADJ NOUN ADJ NOUN NOUN NOUN PUNCT VERB PRON ADP VERB DET ADJ NOUN ADP ADJ NOUN PUNCT', 'tgt_parse_tags': 'amod nsubj nsubj punct advmod det amod amod amod compound appos appos appos punct ROOT dobj prep pcomp det amod dobj prep compound pobj punct', 'source': 'other campaigners, especially the controversial british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'target': 'other campaigners, especially the british activist peter tatchell, attacked him for questioning the universal validity of gay identity.'}
#
# dev dataset:
# Dataset({
#     features: ['id', 'src_tok', 'tgt_tok', 'src_raw', 'tgt_raw', 'src_POS_tags', 'tgt_parse_tags', 'source', 'target'],
#     num_rows: 700
# })
#
# Sample rows:
# {'id': '3257810', 'src_tok': "in addition to sponsoring palestinian terror attacks against israel ( often through jordanian territory , much to king hussein ' s cha ##grin ) , syria also began shell ##ing of israeli civilian communities in north - eastern galilee , from gun em ##pl ##ace ##ments on the syrian - controlled go ##lan heights .", 'tgt_tok': "in addition to sponsoring palestinian attacks against israel ( often through jordanian territory , much to king hussein ' s cha ##grin ) , syria also began shell ##ing of israeli civilian communities in north - eastern galilee , from gun em ##pl ##ace ##ments on the syrian - controlled go ##lan heights .", 'src_raw': "in addition to sponsoring palestinian terror attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'tgt_raw': "in addition to sponsoring palestinian attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'src_POS_tags': 'ADP NOUN ADP VERB ADJ NOUN NOUN ADP PROPN PUNCT ADV ADP ADJ NOUN PUNCT ADV PART NOUN NOUN PUNCT VERB NOUN NOUN PUNCT PUNCT NOUN ADV VERB VERB VERB ADP ADJ ADJ NOUN ADP NOUN PUNCT ADJ NOUN PUNCT ADP NOUN NOUN NOUN NOUN NOUN ADP DET NOUN PUNCT VERB NOUN NOUN NOUN PUNCT', 'tgt_parse_tags': 'prep pobj prep pcomp amod compound dobj prep pobj punct advmod prep amod pobj punct advmod prep pobj dobj punct nummod pobj pobj punct punct nsubj advmod ROOT xcomp xcomp prep amod amod pobj prep amod punct amod pobj punct prep compound pobj pobj pobj pobj prep det npadvmod punct amod compound compound pobj punct', 'source': "in addition to sponsoring palestinian terror attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'target': "in addition to sponsoring palestinian attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights."}
# {'id': '7455549', 'src_tok': 'the game is currently played in 47 countries with more than 30 , 000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004 .', 'tgt_tok': 'the game claims to be currently played in 47 countries with more than 30 , 000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004 .', 'src_raw': 'the game is currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'tgt_raw': 'the game claims to be currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'src_POS_tags': 'DET NOUN VERB ADV VERB ADP NUM NOUN ADP ADJ ADP NUM PUNCT NUM ADJ NOUN NOUN ADV VERB ADP DET ADJ NOUN NOUN ADP ADJ NUM PUNCT', 'tgt_parse_tags': 'det nsubjpass auxpass advmod ROOT prep nummod pobj prep amod quantmod quantmod punct nummod compound compound pobj advmod acl agent det compound compound pobj prep amod pobj punct', 'source': 'the game is currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'target': 'the game claims to be currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.'}
# {'id': '524547829', 'src_tok': 'no part of the valley lies in the area currently occupied by pakistan .', 'tgt_tok': 'no part of the valley lies in the area currently administered by pakistan .', 'src_raw': 'no part of the valley lies in the area currently occupied by pakistan.', 'tgt_raw': 'no part of the valley lies in the area currently administered by pakistan.', 'src_POS_tags': 'DET NOUN ADP DET NOUN VERB ADP DET NOUN ADV VERB ADP NOUN PUNCT', 'tgt_parse_tags': 'det nsubj prep det pobj ROOT prep det pobj advmod acl agent pobj punct', 'source': 'no part of the valley lies in the area currently occupied by pakistan.', 'target': 'no part of the valley lies in the area currently administered by pakistan.'}
#
# test dataset:
# Dataset({
#     features: ['id', 'src_tok', 'tgt_tok', 'src_raw', 'tgt_raw', 'src_POS_tags', 'tgt_parse_tags', 'source', 'target'],
#     num_rows: 1000
# })
#
# Sample rows:
# {'id': 318427508, 'src_tok': 'in april 2009 a brazilian human rights group , torture never again , awarded the five its chico mendes medal , because their rights had been violated .', 'tgt_tok': 'in april 2009 a brazilian human rights group , torture never again , awarded the five its chico mendes medal , under the pre ##text that their rights had been violated .', 'src_raw': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, because their rights had been violated.', 'tgt_raw': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, under the pretext that their rights had been violated.', 'src_POS_tags': 'ADP NOUN NUM DET ADJ ADJ NOUN NOUN PUNCT NOUN ADV ADV PUNCT VERB DET NUM ADJ NOUN NOUN NOUN PUNCT ADP ADJ NOUN VERB VERB VERB PUNCT', 'tgt_parse_tags': 'prep pobj nummod det amod amod compound nsubj punct appos neg advmod punct ROOT det nummod poss compound compound dobj punct mark poss nsubjpass aux auxpass advcl punct', 'source': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, because their rights had been violated.', 'target': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, under the pretext that their rights had been violated.'}
# {'id': 235640083, 'src_tok': 'the 51 day stand ##off and ensuing murder of 76 men , women , and children - - the branch david ##ians - - in wa ##co , texas .', 'tgt_tok': 'the 51 day stand ##off and ensuing deaths of 76 men , women , and children - - the branch david ##ians - - in wa ##co , texas .', 'src_raw': 'the 51 day standoff and ensuing murder of 76 men, women, and children--the branch davidians--in waco, texas.', 'tgt_raw': 'the 51 day standoff and ensuing deaths of 76 men, women, and children--the branch davidians--in waco, texas.', 'src_POS_tags': 'DET NUM NOUN NOUN NOUN CCONJ VERB NOUN ADP NUM NOUN PUNCT NOUN PUNCT CCONJ NOUN PUNCT PUNCT DET NOUN NOUN NOUN PUNCT PUNCT PART NOUN NOUN PUNCT NOUN PUNCT', 'tgt_parse_tags': 'det nummod compound nsubj nsubj cc amod conj prep nummod pobj punct conj punct cc conj punct punct det nsubj conj conj punct punct prep pobj pobj punct ROOT punct', 'source': 'the 51 day standoff and ensuing murder of 76 men, women, and children--the branch davidians--in waco, texas.', 'target': 'the 51 day standoff and ensuing deaths of 76 men, women, and children--the branch davidians--in waco, texas.'}
# {'id': 37561168, 'src_tok': 'mark o ##ate ##n ( born 8 march 1964 , watford ) is a disgrace ##d liberal democrat politician in the united kingdom , and member of parliament for the winchester constituency .', 'tgt_tok': 'mark o ##ate ##n ( born 8 march 1964 , watford ) is a liberal democrat politician in the united kingdom , and member of parliament for the winchester constituency .', 'src_raw': 'mark oaten (born 8 march 1964, watford) is a disgraced liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'tgt_raw': 'mark oaten (born 8 march 1964, watford) is a liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'src_POS_tags': 'NOUN ADJ ADJ ADJ PUNCT VERB NUM NOUN NUM PUNCT NOUN PUNCT VERB DET VERB VERB ADJ ADJ NOUN ADP DET ADJ NOUN PUNCT CCONJ NOUN ADP NOUN ADP DET NOUN NOUN PUNCT', 'tgt_parse_tags': 'nsubj amod amod amod punct parataxis nummod npadvmod nummod punct npadvmod punct ROOT det amod amod amod compound attr prep det amod pobj punct cc conj prep pobj prep det compound pobj punct', 'source': 'mark oaten (born 8 march 1964, watford) is a disgraced liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'target': 'mark oaten (born 8 march 1964, watford) is a liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.'}

# %%
# Remove duplicates
for split in dataset_dict:
    initial_length = len(dataset_dict[split])
    dataset_dict[split], duplicates = remove_duplicates(dataset_dict[split])
    final_length = len(dataset_dict[split])
    print(f"\nRemoved {initial_length - final_length} duplicates from {split} dataset.")
    if not duplicates.empty:
        print(f"\nDuplicates removed from {split} dataset:")
        display(duplicates[['id', 'source', 'target']].sort_values(by='id'))
# Out:
# Removed 6 duplicates from train dataset.
#
# Duplicates removed from train dataset:
#               id                                             source  \
# 15151  170782428  to complete the lineup on their first full-len...
# 47781  170782428  full of the brothers' pop culture obsessions, ...
# 9959   232695029  the armstrongs and fine served jail time, a co...
# 16053  232695029  investigators believe that four people were in...
# 7086   241894774  in addition, they all famously wear purity rin...
# 44713  241894774  they also abstain from alcohol, tobacco, and d...
# 20547  243772559  pettitte ended up getting the victory in the g...
# 47039  243772559  he recorded his 2, 000 career strikeout in the...
# 15269  649752518  madeleine buckingham has served as chief execu...
# 15560  649752518  mother jones (abbreviated mojo) is a far-left ...
# 26400  674355053  experts in branding and marketing, such as wen...
# 46335  674355053  viewed as a brand, hillary clinton is well est...
#
#                                                   target
# 15151  to complete the lineup on their first full-len...
# 47781  full of the brothers' pop culture obsessions, ...
# 9959   the armstrongs and fine served jail time, a co...
# 16053  investigators believe that four people were in...
# 7086   in addition, they all famously wear purity rin...
# 44713  they also report abstaing from alcohol, tobacc...
# 20547  pettitte ended up getting the victory in the g...
# 47039  he recorded his 2, 000th career strikeout in t...
# 15269  madeleine buckingham has served as chief execu...
# 15560  mother jones (abbreviated mojo) is a american ...
# 26400  professionals in branding and marketing, such ...
# 46335  viewed as a brand, hillary clinton is consider...
# Removed 0 duplicates from dev dataset.
#
# Removed 0 duplicates from test dataset.

# %%
# Display the data after removing duplicates
display_data(dataset_dict)
# Out:
# train dataset:
# Dataset({
#     features: ['id', 'src_tok', 'tgt_tok', 'src_raw', 'tgt_raw', 'src_POS_tags', 'tgt_parse_tags', 'source', 'target', '__index_level_0__'],
#     num_rows: 53797
# })
#
# Sample rows:
# {'id': 165188319, 'src_tok': 'ch ##lor ##of ##or ##m " the molecular life ##sa ##ver " an article at oxford university providing interesting facts about ch ##lor ##of ##or ##m .', 'tgt_tok': 'ch ##lor ##of ##or ##m " the molecular life ##sa ##ver " an article at oxford university providing facts about ch ##lor ##of ##or ##m .', 'src_raw': 'chloroform "the molecular lifesaver" an article at oxford university providing interesting facts about chloroform.', 'tgt_raw': 'chloroform "the molecular lifesaver" an article at oxford university providing facts about chloroform.', 'src_POS_tags': 'NOUN NOUN NOUN NOUN NOUN PUNCT DET ADJ NOUN NOUN NOUN PUNCT DET NOUN ADP NOUN NOUN VERB ADJ NOUN ADP NOUN NOUN NOUN NOUN NOUN PUNCT', 'tgt_parse_tags': 'ROOT ROOT ROOT ROOT ROOT punct det amod dobj dobj dobj punct det appos prep compound pobj acl amod dobj prep pobj pobj pobj pobj pobj punct', 'source': 'chloroform "the molecular lifesaver" an article at oxford university providing interesting facts about chloroform.', 'target': 'chloroform "the molecular lifesaver" an article at oxford university providing facts about chloroform.', '__index_level_0__': 0}
# {'id': 123204846, 'src_tok': 'the free software gnu class ##path project is only partially compatible with the current version of sun java .', 'tgt_tok': 'the free software gnu class ##path project is partially compatible with the current version of sun java .', 'src_raw': 'the free software gnu classpath project is only partially compatible with the current version of sun java.', 'tgt_raw': 'the free software gnu classpath project is partially compatible with the current version of sun java.', 'src_POS_tags': 'DET ADJ NOUN NOUN NOUN NOUN NOUN VERB ADV ADV ADJ ADP DET ADJ NOUN ADP NOUN NOUN PUNCT', 'tgt_parse_tags': 'det amod nmod compound compound compound nsubj ROOT advmod advmod acomp prep det amod pobj prep compound pobj punct', 'source': 'the free software gnu classpath project is only partially compatible with the current version of sun java.', 'target': 'the free software gnu classpath project is partially compatible with the current version of sun java.', '__index_level_0__': 1}
# {'id': 706783956, 'src_tok': 'other campaign ##ers , especially the controversial british activist peter ta ##tch ##ell , attacked him for questioning the universal validity of gay identity .', 'tgt_tok': 'other campaign ##ers , especially the british activist peter ta ##tch ##ell , attacked him for questioning the universal validity of gay identity .', 'src_raw': 'other campaigners, especially the controversial british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'tgt_raw': 'other campaigners, especially the british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'src_POS_tags': 'ADJ NOUN NOUN PUNCT ADV DET ADJ ADJ NOUN ADJ NOUN NOUN NOUN PUNCT VERB PRON ADP VERB DET ADJ NOUN ADP ADJ NOUN PUNCT', 'tgt_parse_tags': 'amod nsubj nsubj punct advmod det amod amod amod compound appos appos appos punct ROOT dobj prep pcomp det amod dobj prep compound pobj punct', 'source': 'other campaigners, especially the controversial british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'target': 'other campaigners, especially the british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', '__index_level_0__': 2}
#
# dev dataset:
# Dataset({
#     features: ['id', 'src_tok', 'tgt_tok', 'src_raw', 'tgt_raw', 'src_POS_tags', 'tgt_parse_tags', 'source', 'target'],
#     num_rows: 700
# })
#
# Sample rows:
# {'id': '3257810', 'src_tok': "in addition to sponsoring palestinian terror attacks against israel ( often through jordanian territory , much to king hussein ' s cha ##grin ) , syria also began shell ##ing of israeli civilian communities in north - eastern galilee , from gun em ##pl ##ace ##ments on the syrian - controlled go ##lan heights .", 'tgt_tok': "in addition to sponsoring palestinian attacks against israel ( often through jordanian territory , much to king hussein ' s cha ##grin ) , syria also began shell ##ing of israeli civilian communities in north - eastern galilee , from gun em ##pl ##ace ##ments on the syrian - controlled go ##lan heights .", 'src_raw': "in addition to sponsoring palestinian terror attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'tgt_raw': "in addition to sponsoring palestinian attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'src_POS_tags': 'ADP NOUN ADP VERB ADJ NOUN NOUN ADP PROPN PUNCT ADV ADP ADJ NOUN PUNCT ADV PART NOUN NOUN PUNCT VERB NOUN NOUN PUNCT PUNCT NOUN ADV VERB VERB VERB ADP ADJ ADJ NOUN ADP NOUN PUNCT ADJ NOUN PUNCT ADP NOUN NOUN NOUN NOUN NOUN ADP DET NOUN PUNCT VERB NOUN NOUN NOUN PUNCT', 'tgt_parse_tags': 'prep pobj prep pcomp amod compound dobj prep pobj punct advmod prep amod pobj punct advmod prep pobj dobj punct nummod pobj pobj punct punct nsubj advmod ROOT xcomp xcomp prep amod amod pobj prep amod punct amod pobj punct prep compound pobj pobj pobj pobj prep det npadvmod punct amod compound compound pobj punct', 'source': "in addition to sponsoring palestinian terror attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'target': "in addition to sponsoring palestinian attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights."}
# {'id': '7455549', 'src_tok': 'the game is currently played in 47 countries with more than 30 , 000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004 .', 'tgt_tok': 'the game claims to be currently played in 47 countries with more than 30 , 000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004 .', 'src_raw': 'the game is currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'tgt_raw': 'the game claims to be currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'src_POS_tags': 'DET NOUN VERB ADV VERB ADP NUM NOUN ADP ADJ ADP NUM PUNCT NUM ADJ NOUN NOUN ADV VERB ADP DET ADJ NOUN NOUN ADP ADJ NUM PUNCT', 'tgt_parse_tags': 'det nsubjpass auxpass advmod ROOT prep nummod pobj prep amod quantmod quantmod punct nummod compound compound pobj advmod acl agent det compound compound pobj prep amod pobj punct', 'source': 'the game is currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'target': 'the game claims to be currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.'}
# {'id': '524547829', 'src_tok': 'no part of the valley lies in the area currently occupied by pakistan .', 'tgt_tok': 'no part of the valley lies in the area currently administered by pakistan .', 'src_raw': 'no part of the valley lies in the area currently occupied by pakistan.', 'tgt_raw': 'no part of the valley lies in the area currently administered by pakistan.', 'src_POS_tags': 'DET NOUN ADP DET NOUN VERB ADP DET NOUN ADV VERB ADP NOUN PUNCT', 'tgt_parse_tags': 'det nsubj prep det pobj ROOT prep det pobj advmod acl agent pobj punct', 'source': 'no part of the valley lies in the area currently occupied by pakistan.', 'target': 'no part of the valley lies in the area currently administered by pakistan.'}
#
# test dataset:
# Dataset({
#     features: ['id', 'src_tok', 'tgt_tok', 'src_raw', 'tgt_raw', 'src_POS_tags', 'tgt_parse_tags', 'source', 'target'],
#     num_rows: 1000
# })
#
# Sample rows:
# {'id': 318427508, 'src_tok': 'in april 2009 a brazilian human rights group , torture never again , awarded the five its chico mendes medal , because their rights had been violated .', 'tgt_tok': 'in april 2009 a brazilian human rights group , torture never again , awarded the five its chico mendes medal , under the pre ##text that their rights had been violated .', 'src_raw': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, because their rights had been violated.', 'tgt_raw': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, under the pretext that their rights had been violated.', 'src_POS_tags': 'ADP NOUN NUM DET ADJ ADJ NOUN NOUN PUNCT NOUN ADV ADV PUNCT VERB DET NUM ADJ NOUN NOUN NOUN PUNCT ADP ADJ NOUN VERB VERB VERB PUNCT', 'tgt_parse_tags': 'prep pobj nummod det amod amod compound nsubj punct appos neg advmod punct ROOT det nummod poss compound compound dobj punct mark poss nsubjpass aux auxpass advcl punct', 'source': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, because their rights had been violated.', 'target': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, under the pretext that their rights had been violated.'}
# {'id': 235640083, 'src_tok': 'the 51 day stand ##off and ensuing murder of 76 men , women , and children - - the branch david ##ians - - in wa ##co , texas .', 'tgt_tok': 'the 51 day stand ##off and ensuing deaths of 76 men , women , and children - - the branch david ##ians - - in wa ##co , texas .', 'src_raw': 'the 51 day standoff and ensuing murder of 76 men, women, and children--the branch davidians--in waco, texas.', 'tgt_raw': 'the 51 day standoff and ensuing deaths of 76 men, women, and children--the branch davidians--in waco, texas.', 'src_POS_tags': 'DET NUM NOUN NOUN NOUN CCONJ VERB NOUN ADP NUM NOUN PUNCT NOUN PUNCT CCONJ NOUN PUNCT PUNCT DET NOUN NOUN NOUN PUNCT PUNCT PART NOUN NOUN PUNCT NOUN PUNCT', 'tgt_parse_tags': 'det nummod compound nsubj nsubj cc amod conj prep nummod pobj punct conj punct cc conj punct punct det nsubj conj conj punct punct prep pobj pobj punct ROOT punct', 'source': 'the 51 day standoff and ensuing murder of 76 men, women, and children--the branch davidians--in waco, texas.', 'target': 'the 51 day standoff and ensuing deaths of 76 men, women, and children--the branch davidians--in waco, texas.'}
# {'id': 37561168, 'src_tok': 'mark o ##ate ##n ( born 8 march 1964 , watford ) is a disgrace ##d liberal democrat politician in the united kingdom , and member of parliament for the winchester constituency .', 'tgt_tok': 'mark o ##ate ##n ( born 8 march 1964 , watford ) is a liberal democrat politician in the united kingdom , and member of parliament for the winchester constituency .', 'src_raw': 'mark oaten (born 8 march 1964, watford) is a disgraced liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'tgt_raw': 'mark oaten (born 8 march 1964, watford) is a liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'src_POS_tags': 'NOUN ADJ ADJ ADJ PUNCT VERB NUM NOUN NUM PUNCT NOUN PUNCT VERB DET VERB VERB ADJ ADJ NOUN ADP DET ADJ NOUN PUNCT CCONJ NOUN ADP NOUN ADP DET NOUN NOUN PUNCT', 'tgt_parse_tags': 'nsubj amod amod amod punct parataxis nummod npadvmod nummod punct npadvmod punct ROOT det amod amod amod compound attr prep det amod pobj punct cc conj prep pobj prep det compound pobj punct', 'source': 'mark oaten (born 8 march 1964, watford) is a disgraced liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'target': 'mark oaten (born 8 march 1964, watford) is a liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.'}

# %%
# Remove outliers
for split in dataset_dict:
    initial_length = len(dataset_dict[split])
    new_dataset, outliers = remove_outliers(dataset_dict[split])
    dataset_dict[split] = new_dataset
    final_length = len(dataset_dict[split])
    print(f"\nRemoved {initial_length - final_length} outliers from {split} dataset.")
    if not outliers.empty:
        print(f"\nOutliers removed from {split} dataset:")
        display(outliers[['id', 'source', 'target']].sort_values(by='id'))
# Out:
# Removed 1836 outliers from train dataset.
#
# Outliers removed from train dataset:
#               id                                             source  \
# 15038      82890  at the start of the second intifada, the city ...
# 36345     383530  israelis fear that granting all of the current...
# 48747     537479                           the brown album - primus
# 51141     576892  thus it means that sounds, letters, and words ...
# 39819     871527             carlos the jackal ( infamous criminal)
# ...          ...                                                ...
# 48255  867555377  at school, mendes played ice hockey and soccer...
# 27556  870264330                   notable false suicides/survivors
# 10645  872518444  these conflicts included a customs dispute wit...
# 38639  872530548  in 2002, georgian newspaper svobodnaya gruziya...
# 45244  878683688                      a language or a mere dialect?
#
#                                                   target
# 15038  at the start of the second intifada, the city ...
# 36345  israelis fear that granting all of the current...
# 48747                               brown album - primus
# 51141  thus it means that sounds, letters, and words ...
# 39819                       carlos the jackal (criminal)
# ...                                                  ...
# 48255  at school, mendes played ice hockey and soccer...
# 27556                           false suicides/survivors
# 10645  these conflicts included a customs dispute wit...
# 38639  in 2002, georgian newspaper svobodnaya gruziya...
# 45244                           a language or a dialect?
#
# [1836 rows x 3 columns]
# Removed 28 outliers from dev dataset.
#
# Outliers removed from dev dataset:
#             id                                             source  \
# 492  107449295  googlezon is the name of a fictional future co...
# 157  134280371  the reagan administration provides support to ...
# 340   15326407  at the same time, a growing number of healthca...
# 573  176222946  sahaja yoga aims at providing a trans-cultural...
# 435  214513703  the library system has branches in the beautif...
# 190   21786706  zablocki (1997) and amintrani (2001) assert th...
# 414  230981873  the culture of taiwan is a hybrid blend of con...
# 96   248919990                    1977-2000: traditional marriage
# 308  260859945  horn and kramer give an explanation of these u...
# 618  289044176  hitler made in a public speech in berlin on 4 ...
# 479   34184221                      lonnie latham former minister
# 128  343135393  anna charlotta schrderheim, ne von stapelmohr,...
# 368   36149623  wilson pickett (march 18, 1941 january 19, 200...
# 191  459013878  they named the settlement after the town of be...
# 697  473235829                     d.c. united's early domination
# 391   49857644  however, the "niggertown saturday night" origi...
# 459  499411812  through specific examples of how the governmen...
# 616  529654549  ( interestingly renny cunnack himself was let ...
# 387  579868138  lord and lady mountbatten with muhammad ali ji...
# 344  611030813                                 stintz's rebellion
# 241  622328558  the preamble to the constitution of the episco...
# 490  666096210                         killing of reeva steenkamp
# 652  713515997  the first was the morning show, hosted by spor...
# 165  714287315                   mo'nique, actress and comedienne
# 499   73992111                     un report october 1 1948 www .
# 615  750970534  reviews of the video game were generally mixed...
# 46   832359502  the land of present-day greenville was once th...
# 202   85861129  the charges , however, impacted otto's campaig...
#
#                                                 target
# 492  googlezon is the name of a fictional future co...
# 157  the reagan administration , as part of the col...
# 340  at the same time, a growing number of healthca...
# 573  sahaja yoga aims at providing a trans-cultural...
# 435  the library system has branches in the suburbs...
# 190  zablocki (1997) and amintrani (2001) cite apa ...
# 414  the culture of taiwan is a hybrid blend of con...
# 96                    1977-2000: opposite-sex marriage
# 308  horn and kramer give an explanation of these c...
# 618  hitler `s patience was exhausted only after a ...
# 479                   lonnie latham disgraced minister
# 128  anna charlotta schrderheim, ne von stapelmohr,...
# 368  wilson pickett (march 18, 1941 january 19, 200...
# 191  they named the settlement after the town of be...
# 697                      d.c. united's early successes
# 391  however, the "niggertown saturday night" origi...
# 459  through specific examples of how the governmen...
# 616  (renny cunnack himself was let go as general m...
# 387  lord and lady mountbatten with muhammad ali ji...
# 344                               stintz's alternative
# 241  the preamble to the constitution of the episco...
# 490                           death of reeva steenkamp
# 652  the first was the morning show, hosted by spor...
# 165                     mo'nique, actress and comedian
# 499                 un report october 1 1948 indaily .
# 615  reviews of the video game were generally mixed...
# 46   the land of present-day greenville was once th...
# 202  the false information distributed by her campa...
# Removed 37 outliers from test dataset.
#
# Outliers removed from test dataset:
#             id                                             source  \
# 104    9121384                               bitch is a republic.
# 121   12808397  during his student years he was active in stud...
# 309   35939558  the old market cross in lymm known as "the cro...
# 714   46181875  the judge added more ominously : "if he does n...
# 861   56172585                           arrest, trial, and death
# 990   65221643  its good fun to catch the rabbits and break th...
# 727   76786928  the vandals may have given their name to the r...
# 778   85073053                           she is only 5 feet tall.
# 410  101107569  subsequently, a free and sovereign india absor...
# 643  114139531                    the current allstar line up is:
# 878  130619075  1948 - the city of nazareth, hometown of jesus...
# 278  140577571                                       our jehovah)
# 855  157526265                    views described as islamophobic
# 204  166305315  there were 1,266,264 immigrants who were grant...
# 983  195901260  according to an ad in the paperback edition of...
# 893  208396607  a small african ape living around six million ...
# 589  271808704  her daughter, gemini adams, wrote a groundbrea...
# 666  286442678  valkyrie is a fictional character and marvel c...
# 102  304376949  the music video for "supernova" was shot in bo...
# 524  319059175                     smartftp - advanced gui client
# 819  345715365  jim marrs and ralph schuster have pointed out ...
# 163  380953281  a post-world war ii feel-good movie, the vario...
# 322  412604262  burma , officially the republic of the union o...
# 508  422553504  mehmed "mea" selimovi ( serbian cyrillic: "" ;...
# 502  526889803  the grumman f4f wildcat was an american carrie...
# 540  566390122  the strength and range of the electric force a...
# 155  615471979  although contemporary relations between israel...
# 214  631459731  a 21 year old terrorist , adbel-rahman shaloud...
# 558  682270161  the maxim of liberal conservatism, according t...
# 166  709003703  mr longworth resigned from the bcc on 6 march ...
# 907  713516126                   jaime moyer, actress/ comedienne
# 675  729069133                      briain is a keen arsenal f.c.
# 598  756071900  christian sects and communities that reject th...
# 46   756625814                    the basis of swedish neutrality
# 804  770379043  following the political and border disturbance...
# 262  815772585  the rapid economic and socio-cultural developm...
# 783  825675125  mermaids: the body found, its sequel mermaids:...
#
#                                                 target
# 104                               egypt is a republic.
# 121  during his student years he was active in stud...
# 309  the old market cross in lymm known as "the cro...
# 714  the judge added more: "if he does not repent, ...
# 861                       arrest, trial, and execution
# 990  such hunters often claim that it's good fun to...
# 727  the vandals may have given their name to the r...
# 778                                she is 5 feet tall.
# 410  subsequently, a free and sovereign india absor...
# 643                            the current line up is:
# 878  1948 - the city of nazareth, hometown of jesus...
# 278                                           jehovah)
# 855                      views labeled as islamophobic
# 204  there were 1,266,264 immigrants who were grant...
# 983  according to an ad in the paperback edition of...
# 893  a small african ape living around six million ...
# 589  her daughter, gemini adams, wrote a book entit...
# 666  valkyrie is a fictional character and marvel c...
# 102  the music video for "supernova" was shot in bo...
# 524                              smartftp - gui client
# 819  jim marrs and ralph schuster have pointed out ...
# 163  a post-world war ii feel-good movie, the vario...
# 322  burma , or by decree of a military junta the r...
# 508  mehmed "mea" selimovi (cyrillic: "" ; 26 april...
# 502  the grumman f4f wildcat was an american carrie...
# 540  the strength and range of the electric force a...
# 155  although contemporary relations between israel...
# 214  a 21 year old, adbel-rahman shaloudi, from the...
# 558  the maxim of liberal conservatism, according t...
# 166  mr longworth resigned from the bcc on 6 march ...
# 907                     jaime moyer, actress/ comedian
# 675                           briain is a arsenal f.c.
# 598  christian churches, organizations and communit...
# 46                         basis of swedish neutrality
# 804  following the political and border disturbance...
# 262  the rapid economic and socio-cultural developm...
# 783  mermaids: the body found, its sequel mermaids:...

# %%
# Display the data after removing outliers
display_data(dataset_dict)
# Out:
# train dataset:
# Dataset({
#     features: ['id', 'src_tok', 'tgt_tok', 'src_raw', 'tgt_raw', 'src_POS_tags', 'tgt_parse_tags', 'source', 'target', '__index_level_0__'],
#     num_rows: 51961
# })
#
# Sample rows:
# {'id': 165188319, 'src_tok': 'ch ##lor ##of ##or ##m " the molecular life ##sa ##ver " an article at oxford university providing interesting facts about ch ##lor ##of ##or ##m .', 'tgt_tok': 'ch ##lor ##of ##or ##m " the molecular life ##sa ##ver " an article at oxford university providing facts about ch ##lor ##of ##or ##m .', 'src_raw': 'chloroform "the molecular lifesaver" an article at oxford university providing interesting facts about chloroform.', 'tgt_raw': 'chloroform "the molecular lifesaver" an article at oxford university providing facts about chloroform.', 'src_POS_tags': 'NOUN NOUN NOUN NOUN NOUN PUNCT DET ADJ NOUN NOUN NOUN PUNCT DET NOUN ADP NOUN NOUN VERB ADJ NOUN ADP NOUN NOUN NOUN NOUN NOUN PUNCT', 'tgt_parse_tags': 'ROOT ROOT ROOT ROOT ROOT punct det amod dobj dobj dobj punct det appos prep compound pobj acl amod dobj prep pobj pobj pobj pobj pobj punct', 'source': 'chloroform "the molecular lifesaver" an article at oxford university providing interesting facts about chloroform.', 'target': 'chloroform "the molecular lifesaver" an article at oxford university providing facts about chloroform.', '__index_level_0__': 0}
# {'id': 123204846, 'src_tok': 'the free software gnu class ##path project is only partially compatible with the current version of sun java .', 'tgt_tok': 'the free software gnu class ##path project is partially compatible with the current version of sun java .', 'src_raw': 'the free software gnu classpath project is only partially compatible with the current version of sun java.', 'tgt_raw': 'the free software gnu classpath project is partially compatible with the current version of sun java.', 'src_POS_tags': 'DET ADJ NOUN NOUN NOUN NOUN NOUN VERB ADV ADV ADJ ADP DET ADJ NOUN ADP NOUN NOUN PUNCT', 'tgt_parse_tags': 'det amod nmod compound compound compound nsubj ROOT advmod advmod acomp prep det amod pobj prep compound pobj punct', 'source': 'the free software gnu classpath project is only partially compatible with the current version of sun java.', 'target': 'the free software gnu classpath project is partially compatible with the current version of sun java.', '__index_level_0__': 1}
# {'id': 706783956, 'src_tok': 'other campaign ##ers , especially the controversial british activist peter ta ##tch ##ell , attacked him for questioning the universal validity of gay identity .', 'tgt_tok': 'other campaign ##ers , especially the british activist peter ta ##tch ##ell , attacked him for questioning the universal validity of gay identity .', 'src_raw': 'other campaigners, especially the controversial british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'tgt_raw': 'other campaigners, especially the british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'src_POS_tags': 'ADJ NOUN NOUN PUNCT ADV DET ADJ ADJ NOUN ADJ NOUN NOUN NOUN PUNCT VERB PRON ADP VERB DET ADJ NOUN ADP ADJ NOUN PUNCT', 'tgt_parse_tags': 'amod nsubj nsubj punct advmod det amod amod amod compound appos appos appos punct ROOT dobj prep pcomp det amod dobj prep compound pobj punct', 'source': 'other campaigners, especially the controversial british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'target': 'other campaigners, especially the british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', '__index_level_0__': 2}
#
# dev dataset:
# Dataset({
#     features: ['id', 'src_tok', 'tgt_tok', 'src_raw', 'tgt_raw', 'src_POS_tags', 'tgt_parse_tags', 'source', 'target'],
#     num_rows: 672
# })
#
# Sample rows:
# {'id': '3257810', 'src_tok': "in addition to sponsoring palestinian terror attacks against israel ( often through jordanian territory , much to king hussein ' s cha ##grin ) , syria also began shell ##ing of israeli civilian communities in north - eastern galilee , from gun em ##pl ##ace ##ments on the syrian - controlled go ##lan heights .", 'tgt_tok': "in addition to sponsoring palestinian attacks against israel ( often through jordanian territory , much to king hussein ' s cha ##grin ) , syria also began shell ##ing of israeli civilian communities in north - eastern galilee , from gun em ##pl ##ace ##ments on the syrian - controlled go ##lan heights .", 'src_raw': "in addition to sponsoring palestinian terror attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'tgt_raw': "in addition to sponsoring palestinian attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'src_POS_tags': 'ADP NOUN ADP VERB ADJ NOUN NOUN ADP PROPN PUNCT ADV ADP ADJ NOUN PUNCT ADV PART NOUN NOUN PUNCT VERB NOUN NOUN PUNCT PUNCT NOUN ADV VERB VERB VERB ADP ADJ ADJ NOUN ADP NOUN PUNCT ADJ NOUN PUNCT ADP NOUN NOUN NOUN NOUN NOUN ADP DET NOUN PUNCT VERB NOUN NOUN NOUN PUNCT', 'tgt_parse_tags': 'prep pobj prep pcomp amod compound dobj prep pobj punct advmod prep amod pobj punct advmod prep pobj dobj punct nummod pobj pobj punct punct nsubj advmod ROOT xcomp xcomp prep amod amod pobj prep amod punct amod pobj punct prep compound pobj pobj pobj pobj prep det npadvmod punct amod compound compound pobj punct', 'source': "in addition to sponsoring palestinian terror attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'target': "in addition to sponsoring palestinian attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights."}
# {'id': '7455549', 'src_tok': 'the game is currently played in 47 countries with more than 30 , 000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004 .', 'tgt_tok': 'the game claims to be currently played in 47 countries with more than 30 , 000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004 .', 'src_raw': 'the game is currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'tgt_raw': 'the game claims to be currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'src_POS_tags': 'DET NOUN VERB ADV VERB ADP NUM NOUN ADP ADJ ADP NUM PUNCT NUM ADJ NOUN NOUN ADV VERB ADP DET ADJ NOUN NOUN ADP ADJ NUM PUNCT', 'tgt_parse_tags': 'det nsubjpass auxpass advmod ROOT prep nummod pobj prep amod quantmod quantmod punct nummod compound compound pobj advmod acl agent det compound compound pobj prep amod pobj punct', 'source': 'the game is currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'target': 'the game claims to be currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.'}
# {'id': '524547829', 'src_tok': 'no part of the valley lies in the area currently occupied by pakistan .', 'tgt_tok': 'no part of the valley lies in the area currently administered by pakistan .', 'src_raw': 'no part of the valley lies in the area currently occupied by pakistan.', 'tgt_raw': 'no part of the valley lies in the area currently administered by pakistan.', 'src_POS_tags': 'DET NOUN ADP DET NOUN VERB ADP DET NOUN ADV VERB ADP NOUN PUNCT', 'tgt_parse_tags': 'det nsubj prep det pobj ROOT prep det pobj advmod acl agent pobj punct', 'source': 'no part of the valley lies in the area currently occupied by pakistan.', 'target': 'no part of the valley lies in the area currently administered by pakistan.'}
#
# test dataset:
# Dataset({
#     features: ['id', 'src_tok', 'tgt_tok', 'src_raw', 'tgt_raw', 'src_POS_tags', 'tgt_parse_tags', 'source', 'target'],
#     num_rows: 963
# })
#
# Sample rows:
# {'id': 318427508, 'src_tok': 'in april 2009 a brazilian human rights group , torture never again , awarded the five its chico mendes medal , because their rights had been violated .', 'tgt_tok': 'in april 2009 a brazilian human rights group , torture never again , awarded the five its chico mendes medal , under the pre ##text that their rights had been violated .', 'src_raw': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, because their rights had been violated.', 'tgt_raw': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, under the pretext that their rights had been violated.', 'src_POS_tags': 'ADP NOUN NUM DET ADJ ADJ NOUN NOUN PUNCT NOUN ADV ADV PUNCT VERB DET NUM ADJ NOUN NOUN NOUN PUNCT ADP ADJ NOUN VERB VERB VERB PUNCT', 'tgt_parse_tags': 'prep pobj nummod det amod amod compound nsubj punct appos neg advmod punct ROOT det nummod poss compound compound dobj punct mark poss nsubjpass aux auxpass advcl punct', 'source': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, because their rights had been violated.', 'target': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, under the pretext that their rights had been violated.'}
# {'id': 235640083, 'src_tok': 'the 51 day stand ##off and ensuing murder of 76 men , women , and children - - the branch david ##ians - - in wa ##co , texas .', 'tgt_tok': 'the 51 day stand ##off and ensuing deaths of 76 men , women , and children - - the branch david ##ians - - in wa ##co , texas .', 'src_raw': 'the 51 day standoff and ensuing murder of 76 men, women, and children--the branch davidians--in waco, texas.', 'tgt_raw': 'the 51 day standoff and ensuing deaths of 76 men, women, and children--the branch davidians--in waco, texas.', 'src_POS_tags': 'DET NUM NOUN NOUN NOUN CCONJ VERB NOUN ADP NUM NOUN PUNCT NOUN PUNCT CCONJ NOUN PUNCT PUNCT DET NOUN NOUN NOUN PUNCT PUNCT PART NOUN NOUN PUNCT NOUN PUNCT', 'tgt_parse_tags': 'det nummod compound nsubj nsubj cc amod conj prep nummod pobj punct conj punct cc conj punct punct det nsubj conj conj punct punct prep pobj pobj punct ROOT punct', 'source': 'the 51 day standoff and ensuing murder of 76 men, women, and children--the branch davidians--in waco, texas.', 'target': 'the 51 day standoff and ensuing deaths of 76 men, women, and children--the branch davidians--in waco, texas.'}
# {'id': 37561168, 'src_tok': 'mark o ##ate ##n ( born 8 march 1964 , watford ) is a disgrace ##d liberal democrat politician in the united kingdom , and member of parliament for the winchester constituency .', 'tgt_tok': 'mark o ##ate ##n ( born 8 march 1964 , watford ) is a liberal democrat politician in the united kingdom , and member of parliament for the winchester constituency .', 'src_raw': 'mark oaten (born 8 march 1964, watford) is a disgraced liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'tgt_raw': 'mark oaten (born 8 march 1964, watford) is a liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'src_POS_tags': 'NOUN ADJ ADJ ADJ PUNCT VERB NUM NOUN NUM PUNCT NOUN PUNCT VERB DET VERB VERB ADJ ADJ NOUN ADP DET ADJ NOUN PUNCT CCONJ NOUN ADP NOUN ADP DET NOUN NOUN PUNCT', 'tgt_parse_tags': 'nsubj amod amod amod punct parataxis nummod npadvmod nummod punct npadvmod punct ROOT det amod amod amod compound attr prep det amod pobj punct cc conj prep pobj prep det compound pobj punct', 'source': 'mark oaten (born 8 march 1964, watford) is a disgraced liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'target': 'mark oaten (born 8 march 1964, watford) is a liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.'}

# %%
# Save the processed data for BART seq2seq model
SEQ2SEQ_PATH = "../../data/seq2seq/"
save_processed_data(dataset_dict, SEQ2SEQ_PATH)
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/51961 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/672 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/963 [00:00<?, ? examples/s]

# %%
# Convert the dataset to classification dataset
classification_dataset = convert_to_classification_dataset(SEQ2SEQ_PATH)

# %%
# Lets check sample rows of the classification dataset
display_data(classification_dataset)
# Out:
# train dataset:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 103922
# })
#
# Sample rows:
# {'text': 'in 2013, gervais was named person of the year by peta for his selfless work on curbing animal abuse.', 'label': 1}
# {'text': "tribadism or tribbing is a form of mutual masturbation, sometimes misleadingly called frottage, in which a woman rubs her vulva against her partner's body for sexual stimulation.", 'label': 1}
# {'text': "following the sad demise of ahds, and the cessation of the methods network, the centre for e-research (cerch) was established at king's college london in 2008. the centre's aims are to facilitate interdisciplinary, institutional, national and international collaboration.", 'label': 1}
#
# dev dataset:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 1344
# })
#
# Sample rows:
# {'text': 'richards is a popular politician and member of the bermuda senate for the united bermuda party.', 'label': 1}
# {'text': 'most of these were arcade ports from american laser games (including the infamous mad dog mccree), but virgin interactive and digital pictures also released 3do light gun games.', 'label': 1}
# {'text': "an early adversary of popper's critical rationalism, karl-otto apel attempted a comprehensive refutation of popper's philosophy.", 'label': 0}
#
# test dataset:
# Dataset({
#     features: ['text', 'label'],
#     num_rows: 1926
# })
#
# Sample rows:
# {'text': 'ibn taymiyyah has been influential on subsequent and fundamentalist currents of thought in islam, such as wahhabism, salafism, and the muslim brotherhood.', 'label': 0}
# {'text': 'on the other hand, jennifer holliday, the original effie, appeared on the november 22, 2006 episode of the entertainment news-magazine tv program inside edition, expressing her dissapointment at not being involved in the film project in any way.', 'label': 0}
# {'text': 'a line of yachts, named such due to their competitive prowess.', 'label': 0}

# %%
folder_path = '../../data/seq2seq'
# Load the dataset from disk
seq2seq_dataset = load_from_disk(folder_path)

# %%
display_data(seq2seq_dataset)
# Out:
# train dataset:
# Dataset({
#     features: ['id', 'source', 'target'],
#     num_rows: 51961
# })
#
# Sample rows:
# {'id': 165188319, 'source': 'chloroform "the molecular lifesaver" an article at oxford university providing interesting facts about chloroform.', 'target': 'chloroform "the molecular lifesaver" an article at oxford university providing facts about chloroform.'}
# {'id': 123204846, 'source': 'the free software gnu classpath project is only partially compatible with the current version of sun java.', 'target': 'the free software gnu classpath project is partially compatible with the current version of sun java.'}
# {'id': 706783956, 'source': 'other campaigners, especially the controversial british activist peter tatchell, attacked him for questioning the universal validity of gay identity.', 'target': 'other campaigners, especially the british activist peter tatchell, attacked him for questioning the universal validity of gay identity.'}
#
# dev dataset:
# Dataset({
#     features: ['id', 'source', 'target'],
#     num_rows: 672
# })
#
# Sample rows:
# {'id': '3257810', 'source': "in addition to sponsoring palestinian terror attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights.", 'target': "in addition to sponsoring palestinian attacks against israel (often through jordanian territory, much to king hussein's chagrin), syria also began shelling of israeli civilian communities in north-eastern galilee, from gun emplacements on the syrian-controlled golan heights."}
# {'id': '7455549', 'source': 'the game is currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.', 'target': 'the game claims to be currently played in 47 countries with more than 30,000 gothic chess sets reportedly sold by the gothic chess federation at mid 2004.'}
# {'id': '524547829', 'source': 'no part of the valley lies in the area currently occupied by pakistan.', 'target': 'no part of the valley lies in the area currently administered by pakistan.'}
#
# test dataset:
# Dataset({
#     features: ['id', 'source', 'target'],
#     num_rows: 963
# })
#
# Sample rows:
# {'id': 318427508, 'source': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, because their rights had been violated.', 'target': 'in april 2009 a brazilian human rights group, torture never again, awarded the five its chico mendes medal, under the pretext that their rights had been violated.'}
# {'id': 235640083, 'source': 'the 51 day standoff and ensuing murder of 76 men, women, and children--the branch davidians--in waco, texas.', 'target': 'the 51 day standoff and ensuing deaths of 76 men, women, and children--the branch davidians--in waco, texas.'}
# {'id': 37561168, 'source': 'mark oaten (born 8 march 1964, watford) is a disgraced liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.', 'target': 'mark oaten (born 8 march 1964, watford) is a liberal democrat politician in the united kingdom, and member of parliament for the winchester constituency.'}
